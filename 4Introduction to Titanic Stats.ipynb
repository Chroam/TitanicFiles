# %% [markdown]
# <b><font size="10"> Titanic Notebook </font></b>

# %% [markdown]
# https://www.makeschool.com/mediabook/oa/tutorials/titanic-dataset-tutorial-an-intro-to-data-analysis-and-statistics-n40/titanic-mean-median-mode/

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O 

#Now we can import a data frame, also known as a CSV 
df = pd.read_csv('train.csv')
df.head()

# Any results you write to the current directory are saved as output.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Now we find the shape of the data frame (DF), 891 represents features and 12 represents elements
df.shape
# Out:
# (891, 12)

# %%
#Data types
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Let us find out the sum of null values in each feature.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Some basic calculations
df['Age'].mean()
#You can calculate for any int64 (pandas) or int (Py) data
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
#Why isn't this working? Is it because of the dt?
df['Age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
#You can make a histogram with one command. These visuals represent a distribution of numerical data. How does this differ from
#a bar graph? How can you edit this code to have more labels and descriptions?
df.hist(column="Age")
#df.hist(column="Fare")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015ABA1006C8>]],
#       dtype=object)

# %%
#Who was the oldest?
df['Age'].max()
# Out:
# 80.0

# %%
#What code is used to find the range of the Fares?
print("Range:", np.max() - np.min())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f18225972ef> in <module>
#       1 #What code is used to find the range of the Fares?
# ----> 2 print("Range:", np.max() - np.min())
#
# NameError: name 'np' is not defined

# %%
i = 50
def f():
    i=3
    print(i)
f()
print(i)
# Out:
# 3
# 50
