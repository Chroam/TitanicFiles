# %% [markdown]
# <b><font size="10"> Titanic Notebook </font></b>

# %% [markdown]
# https://www.makeschool.com/mediabook/oa/tutorials/titanic-dataset-tutorial-an-intro-to-data-analysis-and-statistics-n40/probability/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
children = df[df['Age'] < 16]
children.shape
# Out:
# (83, 12)

# %%
children.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8A6DBBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8ABEAC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8AC16A88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8AC4EB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8AC88C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8ACC1DC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8ACFAD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8AD32A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8AD3D588>]],
#       dtype=object)

# %%
living_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
living_children.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B11EEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B5E4A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B60ADC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B642808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B67E208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B6B3BC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B6F2F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B72DF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B735088>]],
#       dtype=object)

# %%
not_surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 0)]
not_surviving_children.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8B38F7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BC80D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BCA9308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BCDECC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BD1DE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BD51088>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BD89108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BDC2248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8BDC8E08>]],
#       dtype=object)

# %%
adult_men = df[(df['Sex'].str.match('male')) & (df['Age'] > 16)]
a_m_survival_rate = adult_men['Survived'].value_counts(normalize=True) * 100
a_m_survival_rate
# Out:
# 0    82.338308
# 1    17.661692
# Name: Survived, dtype: float64

# %%
women_and_children = df[(df['Sex'].str.match("female")) or (df['Age'] < 16)]
w_a_c_survival_rate = women_and_children['Survived'].value_counts(normalize=True) * 100
w_a_c_survival_rate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-ff5378cb80c9> in <module>
# ----> 1 women_and_children = df[(df['Sex'].str.match("female")) or (df['Age'] < 16)]
#       2 w_a_c_survival_rate = women_and_children['Survived'].value_counts(normalize=True) * 100
#       3 w_a_c_survival_rate
#
# D:\DataScience\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
children = df[df['Age'] < 16]
surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
child_chance_of_survival = surviving_children.shape[0] / children.shape[0]
format(child_chance_of_survival, ".0%")
# Out:
# '59%'

# %%
women = df[(df['Sex'] == 'female') & (df['Age'] > 16)]
surviving_women = df[(df['Sex'] == 'female') & (df['Age'] > 16) & (df['Survived'] == 1)]
women_chance_of_survival = surviving_women.shape[0] / women.shape[0]
format(women_chance_of_survival, ".0%")
# Out:
# '77%'

# %%
male = df[(df['Sex'] == 'male') & (df['Age'] > 16)]
surviving_male = df[(df['Sex'] == 'male') & (df['Age'] > 16) & (df['Survived'] == 1)]
male_chance_of_survival = surviving_male.shape[0] / male.shape[0]
format(male_chance_of_survival, ".0%")
# Out:
# '18%'

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_axis = ["Children", "Women", "Men"]
data = [child_chance_of_survival, women_chance_of_survival, male_chance_of_survival]
ax.bar(x_axis, data)
plt.show()

# %%
surviving_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Survived'] == 1)]
surviving_men.describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    71.000000      71.0  71.000000  71.000000  71.000000  71.000000
# mean    485.267606       1.0   1.873239  34.323944   0.267606   0.126761
# std     222.128789       0.0   0.955130  11.798032   0.476827   0.411602
# min      22.000000       1.0   1.000000  17.000000   0.000000   0.000000
# 25%     288.000000       1.0   1.000000  26.500000   0.000000   0.000000
# 50%     513.000000       1.0   1.000000  32.000000   0.000000   0.000000
# 75%     654.500000       1.0   3.000000  41.000000   0.500000   0.000000
# max     890.000000       1.0   3.000000  80.000000   2.000000   2.000000
#
#              Fare
# count   71.000000
# mean    46.731869
# std     85.316448
# min      0.000000
# 25%      8.050000
# 50%     26.550000
# 75%     54.270850
# max    512.329200

# %%
dead_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Survived'] == 0)]
dead_men.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   331.000000     331.0  331.000000  331.000000  331.000000  331.000000
# mean    446.972810       0.0    2.383686   33.496979    0.250755    0.166163
# std     260.482075       0.0    0.779028   12.970596    0.516947    0.566384
# min       1.000000       0.0    1.000000   17.000000    0.000000    0.000000
# 25%     212.000000       0.0    2.000000   23.000000    0.000000    0.000000
# 50%     443.000000       0.0    3.000000   30.000000    0.000000    0.000000
# 75%     680.000000       0.0    3.000000   40.500000    0.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    3.000000    5.000000
#
#              Fare
# count  331.000000
# mean    22.562523
# std     33.570494
# min      0.000000
# 25%      7.854200
# 50%     10.170800
# 75%     26.000000
# max    263.000000

# %%
third_class_adult_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Pclass'] == 3)]
thrird_class_adult_men_survival_rate = third_class_adult_men['Survived'].value_counts(normalize=True) * 100
thrird_class_adult_men_survival_rate
# Out:
# 0    87.037037
# 1    12.962963
# Name: Survived, dtype: float64

# %%
first_class_adult_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Pclass'] == 1)]
first_class_adult_men_survival_rate = first_class_adult_men['Survived'].value_counts(normalize=True) * 100
first_class_adult_men_survival_rate
# Out:
# 0    62.244898
# 1    37.755102
# Name: Survived, dtype: float64

# %%
the_dead = df[df["Survived"] == 0]
the_dead.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D5D5B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D614E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D636AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D66F488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D6A6E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D6E1848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D718208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D750E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B8D75BA48>]],
#       dtype=object)

# %%
sn.barplot(x='Pclass', y='Survived', data=women)

# %%
sn.barplot(x='Pclass', y='Survived', hue="Sex", data=df)

# %%
sn.barplot(x='Sex', y='Survived', hue="Pclass", data=df)
